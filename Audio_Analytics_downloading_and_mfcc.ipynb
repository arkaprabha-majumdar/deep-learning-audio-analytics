# %% [markdown]
# # Dataset for Music Genre Classification

# %%
# !ls
# Out:
# Adhi-Adhi-Raat-Bilal-Saeed.mp3	Patola-Guru-Randhawa.mp3
# BOHEMIA-Diwana.mp3		So-High-Sidhu-Moosewala.mp3
# Falak-soniye.mp3		Wakhra-Swag-Inder-feat-Badshah.mp3
# Jaguar-Muzical-Doctorz.mp3

# %%
# !wget "http://opihi.cs.uvic.ca/sound/genres.tar.gz"
# Out:
# --2020-11-03 05:51:36--  http://opihi.cs.uvic.ca/sound/genres.tar.gz
# Resolving opihi.cs.uvic.ca (opihi.cs.uvic.ca)... 142.104.68.135
# Connecting to opihi.cs.uvic.ca (opihi.cs.uvic.ca)|142.104.68.135|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1225571541 (1.1G) [application/x-gzip]
# Saving to: ‘genres.tar.gz’
#
# genres.tar.gz       100%[===================>]   1.14G  2.09MB/s    in 9m 25s
#
# 2020-11-03 06:01:01 (2.07 MB/s) - ‘genres.tar.gz’ saved [1225571541/1225571541]

# %%
# !tar xzvf "genres.tar.gz"
# Out:
# genres/blues/blues.00030.wav
# genres/blues/blues.00031.wav
# genres/blues/blues.00032.wav
# genres/blues/blues.00033.wav
# genres/blues/blues.00034.wav
# genres/blues/blues.00035.wav
# genres/blues/blues.00036.wav
# genres/blues/blues.00037.wav
# genres/blues/blues.00038.wav
# genres/blues/blues.00039.wav
# genres/blues/blues.00040.wav
# genres/blues/blues.00041.wav
# genres/blues/blues.00042.wav
# genres/blues/blues.00043.wav
# genres/blues/blues.00044.wav
# genres/blues/blues.00045.wav
# genres/blues/blues.00046.wav
# genres/blues/blues.00047.wav
# genres/blues/blues.00048.wav
# genres/blues/blues.00049.wav
# genres/blues/blues.00050.wav
# genres/blues/blues.00051.wav
# genres/blues/blues.00052.wav
# genres/blues/blues.00053.wav
# genres/blues/blues.00054.wav
# genres/blues/blues.00055.wav
# genres/blues/blues.00056.wav
# genres/blues/blues.00057.wav
# genres/blues/blues.00058.wav
# genres/blues/blues.00059.wav
# genres/blues/blues.00060.wav
# genres/blues/blues.00061.wav
# ...

# %%
# !rm "genres.tar.gz"

# %%
import os
import math
import json
import librosa
import numpy as np
import matplotlib.pyplot as plt
#import librosa.display as dsp

dataset_path = "genres"
json_path = "music_genre.json"
sample_rate = 22050
duration = 30 
#8. given in seconds
samples_per_track = sample_rate * duration
#7. let's define the duration before this, which as we know from our data is 30sec for each

def save_mfcc (dataset_path,json_path,n_mfcc=13,n_fft=2048, hop_length=512,num_segments=5):
  #1. first we'll make a dictionary to store the data
  data = {
      "mapping":[],
      "mfcc":[],
      "labels":[]
  }

  ***Hidden code segment***
            print("{}, segment:{}".format(file_path,segment))
    
    with open(json_path,"w") as fp:
      json.dump(data, fp,indent=4)

# %% [markdown]
# If the size/duration of audio files is different for each, thats why we create step 10.
#
# the expected num of segments.
#
# In step 11, we only store the mfcc if its the specific size

# %%
save_mfcc (dataset_path,json_path,num_segments=10)
# Out:
# genres/jazz/jazz.00034.wav, segment:0
# genres/jazz/jazz.00034.wav, segment:1
# genres/jazz/jazz.00034.wav, segment:2
# genres/jazz/jazz.00034.wav, segment:3
# genres/jazz/jazz.00034.wav, segment:4
# genres/jazz/jazz.00034.wav, segment:5
# genres/jazz/jazz.00034.wav, segment:6
# genres/jazz/jazz.00034.wav, segment:7
# genres/jazz/jazz.00034.wav, segment:8
# genres/jazz/jazz.00034.wav, segment:9
# genres/jazz/jazz.00035.wav, segment:0
# genres/jazz/jazz.00035.wav, segment:1
# genres/jazz/jazz.00035.wav, segment:2
# genres/jazz/jazz.00035.wav, segment:3
# genres/jazz/jazz.00035.wav, segment:4
# genres/jazz/jazz.00035.wav, segment:5
# genres/jazz/jazz.00035.wav, segment:6
# genres/jazz/jazz.00035.wav, segment:7
# genres/jazz/jazz.00035.wav, segment:8
# genres/jazz/jazz.00035.wav, segment:9
# genres/jazz/jazz.00036.wav, segment:0
# genres/jazz/jazz.00036.wav, segment:1
# genres/jazz/jazz.00036.wav, segment:2
# genres/jazz/jazz.00036.wav, segment:3
# genres/jazz/jazz.00036.wav, segment:4
# ...
